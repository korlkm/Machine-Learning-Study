# %% [markdown]
# Chap 02-2

# %%
import gdown
gdown.download('https://bit.ly/3q9SZix', '20s_best_book.json',
               quiet=False)
# Out:
# Downloading...
# From: https://bit.ly/3q9SZix
# To: /content/20s_best_book.json
# 100%|██████████| 92.9k/92.9k [00:00<00:00, 33.3MB/s]
# '20s_best_book.json'

# %%
import pandas as pd
books_df = pd.read_json('20s_best_book.json')
books_df.head()
# Out:
#    no  ranking                     bookname   authors publisher  \
# 0   1        1  우리가 빛의 속도로 갈 수 없다면 :김초엽 소설   지은이: 김초엽        허블
# 1   2        2         달러구트 꿈 백화점.이미예 장편소설   지은이: 이미예     팩토리나인
# 2   3        3          지구에서 한아뿐 :정세랑 장편소설   지은이: 정세랑        난다
# 3   4        4           시선으로부터, :정세랑 장편소설   지은이: 정세랑      문학동네
# 4   5        5               아몬드 :손원평 장편소설   지은이: 손원평        창비
#
#   publication_year         isbn13 addition_symbol vol  class_no  \
# 0             2019  9791190090018           03810         813.7
# 1             2020  9791165341909           03810         813.7
# 2             2019  9791188862290           03810         813.7
# 3             2020  9788954672214           03810         813.7
# 4             2017  9788936434267           03810         813.7
#
#          class_nm  loan_count  \
# 0  문학 > 한국문학 > 소설         461
# 1  문학 > 한국문학 > 소설         387
# 2  문학 > 한국문학 > 소설         383
# 3  문학 > 한국문학 > 소설         370
# 4  문학 > 한국문학 > 소설         365
#
# ...

# %% [markdown]
# https://drive.google.com/drive/folders/1wn1YYJHKQOMg3-sbiSSfjWgm9u73O5H1

# %%
import gdown
gdown.download('https://drive.google.com/u/0/uc?id=11mgancWHq69V1B177dnM0cmpzlblJd6_&export=download', '20s_best_book_2.json',quiet = False)
# Out:
# Downloading...
# From: https://drive.google.com/u/0/uc?id=11mgancWHq69V1B177dnM0cmpzlblJd6_&export=download
# To: /content/20s_best_book_2.json
# 100%|██████████| 103k/103k [00:00<00:00, 56.3MB/s]
# '20s_best_book_2.json'

# %%
import pandas as pd
books2_df = pd.read_json('20s_best_book_2.json')
books2_df.head()
# Out:
#    no  ranking                     bookname   authors publisher  \
# 0   1        1  우리가 빛의 속도로 갈 수 없다면 :김초엽 소설   지은이: 김초엽        허블
# 1   2        2         달러구트 꿈 백화점.이미예 장편소설   지은이: 이미예     팩토리나인
# 2   3        3          지구에서 한아뿐 :정세랑 장편소설   지은이: 정세랑        난다
# 3   4        4           시선으로부터, :정세랑 장편소설   지은이: 정세랑      문학동네
# 4   5        5                  아몬드손원평 장편소설       손원평        창비
#
#   publication_year         isbn13 addition_symbol vol  class_no  \
# 0             2019  9791190090018           03810         813.7
# 1             2020  9791165341909           03810         813.7
# 2             2019  9791188862290           03810         813.7
# 3             2020  9788954672214           03810         813.7
# 4             2017  9788936434267           03810         813.7
#
#          class_nm  loan_count  \
# 0  문학 > 한국문학 > 소설         479
# 1  문학 > 한국문학 > 소설         407
# 2  문학 > 한국문학 > 소설         391
# 3  문학 > 한국문학 > 소설         379
# 4  문학 > 한국문학 > 소설         375
#
# ...

# %%
books = books_df[['no', 'ranking', 'bookname', 'authors', 'publisher', 'publication_year', 'isbn13']]
books.head()
# Out:
#    no  ranking                     bookname   authors publisher  \
# 0   1        1  우리가 빛의 속도로 갈 수 없다면 :김초엽 소설   지은이: 김초엽        허블
# 1   2        2         달러구트 꿈 백화점.이미예 장편소설   지은이: 이미예     팩토리나인
# 2   3        3          지구에서 한아뿐 :정세랑 장편소설   지은이: 정세랑        난다
# 3   4        4           시선으로부터, :정세랑 장편소설   지은이: 정세랑      문학동네
# 4   5        5               아몬드 :손원평 장편소설   지은이: 손원평        창비
#
#   publication_year         isbn13
# 0             2019  9791190090018
# 1             2020  9791165341909
# 2             2019  9791188862290
# 3             2020  9788954672214
# 4             2017  9788936434267

# %%
books_df.loc[[0,1], ['bookname','authors']]
# Out:
#                       bookname   authors
# 0  우리가 빛의 속도로 갈 수 없다면 :김초엽 소설   지은이: 김초엽
# 1         달러구트 꿈 백화점.이미예 장편소설   지은이: 이미예

# %%
books_df.loc[0:1, 'bookname':'authors']
# Out:
#                       bookname   authors
# 0  우리가 빛의 속도로 갈 수 없다면 :김초엽 소설   지은이: 김초엽
# 1         달러구트 꿈 백화점.이미예 장편소설   지은이: 이미예

# %%
books = books_df.loc[:, 'no':'isbn13']
books.head()
# Out:
#    no  ranking                     bookname   authors publisher  \
# 0   1        1  우리가 빛의 속도로 갈 수 없다면 :김초엽 소설   지은이: 김초엽        허블
# 1   2        2         달러구트 꿈 백화점.이미예 장편소설   지은이: 이미예     팩토리나인
# 2   3        3          지구에서 한아뿐 :정세랑 장편소설   지은이: 정세랑        난다
# 3   4        4           시선으로부터, :정세랑 장편소설   지은이: 정세랑      문학동네
# 4   5        5               아몬드 :손원평 장편소설   지은이: 손원평        창비
#
#   publication_year         isbn13
# 0             2019  9791190090018
# 1             2020  9791165341909
# 2             2019  9791188862290
# 3             2020  9788954672214
# 4             2017  9788936434267

# %%
books_df.loc[0:3, 'no':'authors']
# Out:
#    no  ranking                     bookname   authors
# 0   1        1  우리가 빛의 속도로 갈 수 없다면 :김초엽 소설   지은이: 김초엽
# 1   2        2         달러구트 꿈 백화점.이미예 장편소설   지은이: 이미예
# 2   3        3          지구에서 한아뿐 :정세랑 장편소설   지은이: 정세랑
# 3   4        4           시선으로부터, :정세랑 장편소설   지은이: 정세랑

# %% [markdown]
# loc은 인덱스 이름으로 찾는거고 iloc은 인덱스 몇번째 행인지로 찾는거임

# %%
books_df.loc[ ::2, 'no':'isbn13':2].head()
# Out:
#    no                     bookname publisher         isbn13
# 0   1  우리가 빛의 속도로 갈 수 없다면 :김초엽 소설         허블  9791190090018
# 2   3          지구에서 한아뿐 :정세랑 장편소설         난다  9791188862290
# 4   5               아몬드 :손원평 장편소설         창비  9788936434267
# 6   7          목소리를 드릴게요 :정세랑 소설집         아작  9791165300005
# 8   9                   선량한 차별주의자         창비  9788936477196

# %%
import requests
isbn = 9791190090018
url = 'http://www.yes24.com/Product/Search?domain=BOOK&query={}'
r = requests.get(url.format(isbn))

# %%
print(r.text)

# %% [markdown]
# http://www.yes24.com/Product/Search?domain=BOOK&query=9791190090018

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(r.text, 'html.parser')

# %%
prd_link = soup.find('a', attrs={'class':'gd_name'})
print(prd_link)
# Out:
# <a class="gd_name" href="/Product/Goods/74261416" onclick="setSCode('101_005_003_001');setGoodsClickExtraCodeHub('032', '9791190090018', '74261416', '0');">우리가 빛의 속도로 갈 수 없다면</a>

# %%
print(prd_link['href'])
# Out:
# /Product/Goods/74261416

# %%
url = 'http://www.yes24.com'+prd_link['href']
r = requests.get(url)
print(r.text)

# %%
soup = BeautifulSoup(r.text, 'html.parser')
prd_detail = soup.find('div', attrs={'id':'infoset_specific'})
print(prd_detail)

# %%
prd_tr_list = prd_detail.find_all('tr')
print(prd_tr_list)

# %%
for tr in prd_tr_list:
  if tr.find('th').get_text() == '쪽수, 무게, 크기':
    page_td = tr.find('td').get_text()
    break

# %%
print(page_td)

# %%
print(page_td.split()[0])

# %%
import requests
isbn = 9791165341909
url = 'http://www.yes24.com/Product/Search?domain=BOOK&query={}'
r = requests.get(url.format(isbn))

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(r.text, 'html.parser')

# %%
prd_link = soup.find('a', attrs={'class':'gd_name'})
print(prd_link)
# Out:
# <a class="gd_name" href="/Product/Goods/91065309" onclick="setSCode('101_005_003_001');setGoodsClickExtraCodeHub('032', '9791165341909', '91065309', '0');">달러구트 꿈 백화점 (레인보우 에디션)</a>

# %%
print(prd_link['href'])
# Out:
# /Product/Goods/91065309

# %%
url = 'http://www.yes24.com'+prd_link['href']
r = requests.get(url)
print(r.text)

# %%
soup = BeautifulSoup(r.text, 'html.parser')
prd_detail = soup.find('div', attrs={'id':'infoset_specific'})
print(prd_detail)

# %%
prd_tr_list = prd_detail.find_all('tr')
print(prd_tr_list)

# %%
for tr in prd_tr_list:
  if tr.find('th').get_text() == '쪽수, 무게, 크기':
    page_td = tr.find('td').get_text()
    break

# %%
print(page_td)
# Out:
# 300쪽 | 358g | 134*200*20mm

# %%
print(page_td.split()[0])
# Out:
# 300쪽
